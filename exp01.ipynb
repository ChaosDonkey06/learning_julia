# %%
using Pkg
using DifferentialEquations
using SimpleDiffEq
using DataFrames
using StatsPlots
using BenchmarkTools


function sir_ode!(du,u,p,t)
    (S,I,R) = u
    (β,c,γ) = p
    N = S+I+R
    @inbounds begin
        du[1] = -β*c*I/N*S
        du[2] = β*c*I/N*S - γ*I
        du[3] = γ*I
    end
    nothing
end

δt = 0.1
tmax = 40.0
tspan = (0.0,tmax)
t = 0.0:δt:tmax;

u0 = [990.0,10.0,0.0]; # S,I.R
p = [0.05,10.0,0.25]; # β,c,γ

prob_ode = ODEProblem(sir_ode!,u0,tspan,p);

sol_ode = solve(prob_ode);

df_ode = DataFrame(sol_ode(t)')
df_ode[!,:t] = t;

@df df_ode plot(:t,
    [:x1 :x2 :x3],
    label=["S" "I" "R"],
    xlabel="Time",
    ylabel="Number")
# Out:
# ┌ Info: Precompiling DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# └ @ Base loading.jl:1192
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e]
# │   exception = Required dependency ZygoteRules [700de1a5-db45-46bc-99cf-38207098b444] failed to load from a cache file.
# └ @ Base loading.jl:969
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for ForwardDiff [f6369f11-7733-5829-9624-2563aa707210]
# │   exception = Required dependency CommonSubexpressions [bbf7d656-a473-5ed7-a52c-81e309532950] failed to load from a cache file.
# └ @ Base loading.jl:969
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for NLSolversBase [d41bc354-129a-5804-8e4c-c37616107c6c]
# │   exception = Required dependency CommonSubexpressions [bbf7d656-a473-5ed7-a52c-81e309532950] failed to load from a cache file.
# └ @ Base loading.jl:969
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for ForwardDiff [f6369f11-7733-5829-9624-2563aa707210]
# │   exception = Required dependency CommonSubexpressions [bbf7d656-a473-5ed7-a52c-81e309532950] failed to load from a cache file.
# └ @ Base loading.jl:969
# ┌ Warning: Module NLSolversBase with build ID 219134080020788 is missing from the cache.
# │ This may mean NLSolversBase [d41bc354-129a-5804-8e4c-c37616107c6c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# WARNING: Method definition vec(Number) in module DiffEqDiffTools at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/DiffEqDiffTools/uD0fb/src/jacobians.jl:114 overwritten in module FiniteDiff at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/FiniteDiff/EBys0/src/jacobians.jl:128.
# ┌ Warning: Module ForwardDiff with build ID 219143859297385 is missing from the cache.
# │ This may mean ForwardDiff [f6369f11-7733-5829-9624-2563aa707210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module OrdinaryDiffEq with build ID 219160674330517 is missing from the cache.
# │ This may mean OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module DiffEqBase with build ID 219080631164404 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# │   exception = ErrorException("Required dependency ForwardDiff [f6369f11-7733-5829-9624-2563aa707210] failed to load from a cache file.")
# └ @ Base loading.jl:969
# ┌ Info: Recompiling stale cache file /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/compiled/v1.0/DiffEqBase/oaevG.ji for DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e]
# └ @ Base loading.jl:1190
# ┌ Info: Precompiling DiffEqNoiseProcess [77a26b50-5914-5dd7-bc55-306e6241c503]
# └ @ Base loading.jl:1192
# ┌ Info: Precompiling SteadyStateDiffEq [9672c7b4-1e72-59bd-8a11-6ac3964bc41f]
# └ @ Base loading.jl:1192
# ┌ Warning: Module ForwardDiff with build ID 219143859297385 is missing from the cache.
# │ This may mean ForwardDiff [f6369f11-7733-5829-9624-2563aa707210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# WARNING: Method definition vec(Number) in module DiffEqDiffTools at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/DiffEqDiffTools/uD0fb/src/jacobians.jl:114 overwritten in module FiniteDiff at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/FiniteDiff/EBys0/src/jacobians.jl:128.
# ┌ Warning: Module ForwardDiff with build ID 219143859297385 is missing from the cache.
# │ This may mean ForwardDiff [f6369f11-7733-5829-9624-2563aa707210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# WARNING: Method definition vec(Number) in module DiffEqDiffTools at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/DiffEqDiffTools/uD0fb/src/jacobians.jl:114 overwritten in module FiniteDiff at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/FiniteDiff/EBys0/src/jacobians.jl:128.
# ┌ Warning: The call to compilecache failed to create a usable precompiled cache file for SteadyStateDiffEq [9672c7b4-1e72-59bd-8a11-6ac3964bc41f]
# │   exception = ErrorException("Required dependency ForwardDiff [f6369f11-7733-5829-9624-2563aa707210] failed to load from a cache file.")
# └ @ Base loading.jl:969
# ┌ Info: Precompiling StochasticDiffEq [789caeaf-c7a9-5a7d-9973-96adeb23e2a0]
# └ @ Base loading.jl:1192
# ┌ Warning: Module SparseDiffTools with build ID 219332678687143 is missing from the cache.
# │ This may mean SparseDiffTools [47a9eef4-7e08-11e9-0b38-333d64bd3804] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Info: Precompiling BoundaryValueDiffEq [764a87c0-6b3e-53db-9096-fe964310641d]
# └ @ Base loading.jl:1192
# ┌ Info: Precompiling Sundials [c3572dad-4567-51f8-b174-8c6c989267f4]
# └ @ Base loading.jl:1192
# ┌ Info: Precompiling DelayDiffEq [bcd4f6db-9728-5f36-b5f7-82caef46ccdb]
# └ @ Base loading.jl:1192
# ┌ Warning: Module OrdinaryDiffEq with build ID 219328457273553 is missing from the cache.
# │ This may mean OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Info: Precompiling DiffEqJump [c894b116-72e5-5b58-be3c-e6d8d4ac2b12]
# └ @ Base loading.jl:1192
# ┌ Info: Precompiling DiffEqFinancial [5a0ffddc-d203-54b0-88ba-2c03c0fc2e67]
# └ @ Base loading.jl:1192
# ┌ Info: Precompiling MultiScaleArrays [f9640e96-87f6-5992-9c3b-0743c6a49ffa]
# └ @ Base loading.jl:1192
# ┌ Warning: Module StochasticDiffEq with build ID 219377636806268 is missing from the cache.
# │ This may mean StochasticDiffEq [789caeaf-c7a9-5a7d-9973-96adeb23e2a0] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Info: Precompiling DiffEqPhysics [055956cb-9e8b-5191-98cc-73ae4a59e68a]
# └ @ Base loading.jl:1192
# ┌ Warning: Module ForwardDiff with build ID 219143859297385 is missing from the cache.
# │ This may mean ForwardDiff [f6369f11-7733-5829-9624-2563aa707210] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Info: Precompiling SimpleDiffEq [05bca326-078c-5bf0-a5bf-ce7c7982d7fd]
# └ @ Base loading.jl:1192
# ┌ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1192
# ┌ Info: Precompiling StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd]
# └ @ Base loading.jl:1192
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Type{Dates.Date}, Dates.Date) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Type{Dates.DateTime}, Dates.DateTime) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Type{Dates.Time}, Dates.Time) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Type{P<:Dates.Period}, P<:Dates.Period) where {P<:Dates.Period} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Type{#s236} where #s236<:AbstractChar, AbstractChar) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Type{T}, T) where {T} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Type{V<:(Base.Val{x} where x)}, Any, Any, Any) where {V<:(Base.Val{x} where x)} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Integer) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Union{Array{F<:Function, 1}, Array{F<:Function, 2}, F<:Function}) where {F<:Function} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Function, Number, Number) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Union{Array{F<:Function, 1}, Array{F<:Function, 2}, F<:Function}, Union{Array{G<:Function, 1}, Array{G<:Function, 2}, G<:Function}, Union{Array{H<:Function, 1}, Array{H<:Function, 2}, H<:Function}, AbstractArray{T, 1} where T) where {F<:Function, G<:Function, H<:Function} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Union{Array{F<:Function, 1}, Array{F<:Function, 2}, F<:Function}, Union{Array{G<:Function, 1}, Array{G<:Function, 2}, G<:Function}, Union{Array{H<:Function, 1}, Array{H<:Function, 2}, H<:Function}, Number, Number) where {F<:Function, G<:Function, H<:Function} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Union{Array{F<:Function, 1}, Array{F<:Function, 2}, F<:Function}, Union{Array{G<:Function, 1}, Array{G<:Function, 2}, G<:Function}, Union{Array{H<:Function, 1}, Array{H<:Function, 2}, H<:Function}, Number, Number, Any) where {F<:Function, G<:Function, H<:Function} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Union{Array{F<:Function, 1}, Array{F<:Function, 2}, F<:Function}, Union{Array{G<:Function, 1}, Array{G<:Function, 2}, G<:Function}, AbstractArray{T, 1} where T) where {F<:Function, G<:Function} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Union{Array{F<:Function, 1}, Array{F<:Function, 2}, F<:Function}, Union{Array{G<:Function, 1}, Array{G<:Function, 2}, G<:Function}, Number, Number) where {F<:Function, G<:Function} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Union{Array{F<:Function, 1}, Array{F<:Function, 2}, F<:Function}, Union{Array{G<:Function, 1}, Array{G<:Function, 2}, G<:Function}, Number, Number, Any) where {F<:Function, G<:Function} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Union{Array{F<:Function, 1}, Array{F<:Function, 2}, F<:Function}, Any) where {F<:Function} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, AbstractArray{T<:Union{Base.Missing, Number}, 3}, Any...) where {T<:Union{Base.Missing, Number}} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Base.AbstractDict{K, V} where V where K) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, AbstractArray{#s236, 1} where #s236<:Tuple) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, AbstractArray{T, 1} where T, AbstractArray{T, 1} where T, Function) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, AbstractArray{T, 1} where T, AbstractArray{T, 1} where T, AbstractArray{T, 2} where T) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, AbstractArray{F<:Function, N} where N, Number, Number) where {F<:Function} in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Tuple) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Any) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Any, Any) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Any, Any, Any) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# WARNING: Method definition apply_recipe(Base.AbstractDict{Symbol, Any}, Any, Any, Any, Any, Any...) in module RecipesPipeline at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273 overwritten in module Plots at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/RecipesBase/G4s6f/src/RecipesBase.jl:273.
# ERROR: LoadError: No deps.jl file could be found. Please try running Pkg.build("Arpack").
# Currently, the build command might fail when Julia has been built from source
# and the recommendation is to use the official binaries from julialang.org.
# For more info see https://github.com/JuliaLinearAlgebra/Arpack.jl/issues/5.
#
# Stacktrace:
#  [1] top-level scope at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/Arpack/zCmTA/src/Arpack.jl:19
#  [2] include_relative(::Module, ::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [3] include(::Module, ::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [4] top-level scope at none:2
#  [5] eval at ./boot.jl:319 [inlined]
#  [6] eval(::Expr) at ./client.jl:393
#  [7] top-level scope at ./none:3
# in expression starting at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/Arpack/zCmTA/src/Arpack.jl:16
# ERROR: LoadError: LoadError: Failed to precompile Arpack [7d9fca2a-8960-54d3-9f78-7d1dccf2cb97] to /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/compiled/v1.0/Arpack/X5VZL.ji.
# Stacktrace:
#  [1] error(::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [2] compilecache(::Base.PkgId, ::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [3] _require(::Base.PkgId) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [4] require(::Base.PkgId) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:? (repeats 2 times)
#  [5] include at ./boot.jl:317 [inlined]
#  [6] include_relative(::Module, ::String) at ./loading.jl:1044
#  [7] include at ./sysimg.jl:29 [inlined]
#  [8] include(::String) at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/MultivariateStats/HTpHt/src/MultivariateStats.jl:1
#  [9] top-level scope at none:0
#  [10] include_relative(::Module, ::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [11] include(::Module, ::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [12] top-level scope at none:2
#  [13] eval at ./boot.jl:319 [inlined]
#  [14] eval(::Expr) at ./client.jl:393
#  [15] top-level scope at ./none:3
# in expression starting at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/MultivariateStats/HTpHt/src/kpca.jl:3
# in expression starting at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/MultivariateStats/HTpHt/src/MultivariateStats.jl:123
# ERROR: LoadError: Failed to precompile MultivariateStats [6f286f6a-111f-5878-ab1e-185364afe411] to /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/compiled/v1.0/MultivariateStats/l7I74.ji.
# Stacktrace:
#  [1] error(::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [2] compilecache(::Base.PkgId, ::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [3] _require(::Base.PkgId) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [4] require(::Base.PkgId) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:? (repeats 2 times)
#  [5] include_relative(::Module, ::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [6] include(::Module, ::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [7] top-level scope at none:2
#  [8] eval at ./boot.jl:319 [inlined]
#  [9] eval(::Expr) at ./client.jl:393
#  [10] top-level scope at ./none:3
# in expression starting at /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/packages/StatsPlots/ie0L8/src/StatsPlots.jl:21
# Failed to precompile StatsPlots [f3b207a7-027a-5e70-b257-86293d7955fd] to /Users/chaosdonkey06/.juliapro/JuliaPro_v1.0.5-2/compiled/v1.0/StatsPlots/SiylL.ji.
#
# Stacktrace:
#  [1] error(::String) at /Applications/JuliaPro-1.0.5-2.app/Contents/Resources/julia/Contents/Resources/julia/lib/julia/sys.dylib:?
#  [2] compilecache(::Base.PkgId, ::String) at ./loading.jl:1203
#  [3] _require(::Base.PkgId) at ./loading.jl:960
#  [4] require(::Base.PkgId) at ./loading.jl:858
#  [5] require(::Module, ::Symbol) at ./loading.jl:853
#  [6] top-level scope at In[1]:5
